# %%
from measure_diversity.embeddings.SBERT import encode_sentences
from measure_diversity.measure import mean_pairwise_distance, distance_dispersion, cluster_inertia_diversity, convex_hull_volume, radius_diversity
import os

# %%
def read_sentences_from_txt(filepath):
    with open(filepath, "r", encoding="utf-8") as f:
        return [line.strip() for line in f if line.strip()]

# %%
BASE_DIR = os.path.dirname(os.path.dirname(os.path.abspath("")))
DATA_PATH_mrpc_high = os.path.join(BASE_DIR, "Diversity-Measurement/pilot_datasets/semantic_diversity/STS_based/mrpc_high_diversity.txt")
DATA_PATH_mrpc_low = os.path.join(BASE_DIR, "Diversity-Measurement/pilot_datasets/semantic_diversity/STS_based/mrpc_low_diversity.txt")

DATA_PATH_qqp_high = os.path.join(BASE_DIR, "Diversity-Measurement/pilot_datasets/semantic_diversity/STS_based/qqp_high_diversity.txt")
DATA_PATH_qqp_low = os.path.join(BASE_DIR, "Diversity-Measurement/pilot_datasets/semantic_diversity/STS_based/qqp_low_diversity.txt")

DATA_PATH_stsb_high = os.path.join(BASE_DIR, "Diversity-Measurement/pilot_datasets/semantic_diversity/STS_based/qqp_high_diversity.txt")
DATA_PATH_stsb_low = os.path.join(BASE_DIR, "Diversity-Measurement/pilot_datasets/semantic_diversity/STS_based/qqp_low_diversity.txt")

DATA_PATH_20newsgroups_2 = os.path.join(BASE_DIR, "Diversity-Measurement/pilot_datasets/semantic_diversity/topic_based/20newsgroups_2-topics.txt")
DATA_PATH_20newsgroups_4 = os.path.join(BASE_DIR, "Diversity-Measurement/pilot_datasets/semantic_diversity/topic_based/20newsgroups_4-topics.txt")
DATA_PATH_20newsgroups_6 = os.path.join(BASE_DIR, "Diversity-Measurement/pilot_datasets/semantic_diversity/topic_based/20newsgroups_6-topics.txt")
DATA_PATH_20newsgroups_8 = os.path.join(BASE_DIR, "Diversity-Measurement/pilot_datasets/semantic_diversity/topic_based/20newsgroups_8-topics.txt")
DATA_PATH_20newsgroups_10 = os.path.join(BASE_DIR, "Diversity-Measurement/pilot_datasets/semantic_diversity/topic_based/20newsgroups_10-topics.txt")
DATA_PATH_20newsgroups_12 = os.path.join(BASE_DIR, "Diversity-Measurement/pilot_datasets/semantic_diversity/topic_based/20newsgroups_12-topics.txt")
DATA_PATH_20newsgroups_14 = os.path.join(BASE_DIR, "Diversity-Measurement/pilot_datasets/semantic_diversity/topic_based/20newsgroups_14-topics.txt")
DATA_PATH_20newsgroups_16 = os.path.join(BASE_DIR, "Diversity-Measurement/pilot_datasets/semantic_diversity/topic_based/20newsgroups_16-topics.txt")
DATA_PATH_20newsgroups_18 = os.path.join(BASE_DIR, "Diversity-Measurement/pilot_datasets/semantic_diversity/topic_based/20newsgroups_18-topics.txt")
DATA_PATH_20newsgroups_20 = os.path.join(BASE_DIR, "Diversity-Measurement/pilot_datasets/semantic_diversity/topic_based/20newsgroups_20-topics.txt")

DATA_PATH_agnews_1 = os.path.join(BASE_DIR, "Diversity-Measurement/pilot_datasets/semantic_diversity/topic_based/agnews_1-topic.txt")
DATA_PATH_agnews_2 = os.path.join(BASE_DIR, "Diversity-Measurement/pilot_datasets/semantic_diversity/topic_based/agnews_2-topics.txt")
DATA_PATH_agnews_3 = os.path.join(BASE_DIR, "Diversity-Measurement/pilot_datasets/semantic_diversity/topic_based/agnews_3-topics.txt")
DATA_PATH_agnews_4 = os.path.join(BASE_DIR, "Diversity-Measurement/pilot_datasets/semantic_diversity/topic_based/agnews_4-topics.txt")

DATA_PATH_reuters_2 = os.path.join(BASE_DIR, "Diversity-Measurement/pilot_datasets/semantic_diversity/topic_based/reuters_2-topics.txt")
DATA_PATH_reuters_4 = os.path.join(BASE_DIR, "Diversity-Measurement/pilot_datasets/semantic_diversity/topic_based/reuters_4-topics.txt")
DATA_PATH_reuters_6 = os.path.join(BASE_DIR, "Diversity-Measurement/pilot_datasets/semantic_diversity/topic_based/reuters_6-topics.txt")
DATA_PATH_reuters_8 = os.path.join(BASE_DIR, "Diversity-Measurement/pilot_datasets/semantic_diversity/topic_based/reuters_8-topics.txt")

# %%
sentences_mrpc_low = read_sentences_from_txt(DATA_PATH_mrpc_low)
print(f"Loaded {len(sentences_mrpc_low)} sentences.")
print(sentences_mrpc_low[:3])
sentences_mrpc_high = read_sentences_from_txt(DATA_PATH_mrpc_high)
print(f"Loaded {len(sentences_mrpc_high)} sentences.")
print(sentences_mrpc_high[:3])

sentences_qqp_low = read_sentences_from_txt(DATA_PATH_qqp_low)
print(f"Loaded {len(sentences_qqp_low)} sentences.")
print(sentences_qqp_low[:3])
sentences_qqp_high = read_sentences_from_txt(DATA_PATH_qqp_high)
print(f"Loaded {len(sentences_qqp_high)} sentences.")
print(sentences_qqp_high[:3])

sentences_stsb_low = read_sentences_from_txt(DATA_PATH_stsb_low)
print(f"Loaded {len(sentences_stsb_low)} sentences.")
print(sentences_stsb_low[:3])
sentences_stsb_high = read_sentences_from_txt(DATA_PATH_stsb_high)
print(f"Loaded {len(sentences_stsb_high)} sentences.")
print(sentences_stsb_high[:3])

sentences_20newsgroups_2 = read_sentences_from_txt(DATA_PATH_20newsgroups_2)
print(f"Loaded {len(sentences_20newsgroups_2)} sentences.")
print(sentences_20newsgroups_2[:3])
sentences_20newsgroups_4 = read_sentences_from_txt(DATA_PATH_20newsgroups_4)
print(f"Loaded {len(sentences_20newsgroups_4)} sentences.")
print(sentences_20newsgroups_4[:3])
sentences_20newsgroups_6 = read_sentences_from_txt(DATA_PATH_20newsgroups_6)
print(f"Loaded {len(sentences_20newsgroups_6)} sentences.")
print(sentences_20newsgroups_6[:3])
sentences_20newsgroups_8 = read_sentences_from_txt(DATA_PATH_20newsgroups_8)
print(f"Loaded {len(sentences_20newsgroups_8)} sentences.")
print(sentences_20newsgroups_8[:3])
sentences_20newsgroups_10 = read_sentences_from_txt(DATA_PATH_20newsgroups_10)
print(f"Loaded {len(sentences_20newsgroups_10)} sentences.")
print(sentences_20newsgroups_10[:3])
sentences_20newsgroups_12 = read_sentences_from_txt(DATA_PATH_20newsgroups_12)
print(f"Loaded {len(sentences_20newsgroups_12)} sentences.")
print(sentences_20newsgroups_12[:3])
sentences_20newsgroups_14 = read_sentences_from_txt(DATA_PATH_20newsgroups_14)
print(f"Loaded {len(sentences_20newsgroups_14)} sentences.")
print(sentences_20newsgroups_14[:3])
sentences_20newsgroups_16 = read_sentences_from_txt(DATA_PATH_20newsgroups_16)
print(f"Loaded {len(sentences_20newsgroups_16)} sentences.")
print(sentences_20newsgroups_16[:3])
sentences_20newsgroups_18 = read_sentences_from_txt(DATA_PATH_20newsgroups_18)
print(f"Loaded {len(sentences_20newsgroups_18)} sentences.")
print(sentences_20newsgroups_18[:3])
sentences_20newsgroups_20 = read_sentences_from_txt(DATA_PATH_20newsgroups_20)
print(f"Loaded {len(sentences_20newsgroups_20)} sentences.")
print(sentences_20newsgroups_20[:3])  

sentences_agnews_1 = read_sentences_from_txt(DATA_PATH_agnews_1)
print(f"Loaded {len(sentences_agnews_1)} sentences.")
print(sentences_agnews_1[:3])
sentences_agnews_2 = read_sentences_from_txt(DATA_PATH_agnews_2)
print(f"Loaded {len(sentences_agnews_2)} sentences.")
print(sentences_agnews_2[:3])
sentences_agnews_3 = read_sentences_from_txt(DATA_PATH_agnews_3)
print(f"Loaded {len(sentences_agnews_3)} sentences.")
print(sentences_agnews_3[:3])
sentences_agnews_4 = read_sentences_from_txt(DATA_PATH_agnews_4)
print(f"Loaded {len(sentences_agnews_4)} sentences.")
print(sentences_agnews_4[:3])

sentences_reuters_2 = read_sentences_from_txt(DATA_PATH_reuters_2)
print(f"Loaded {len(sentences_reuters_2)} sentences.")
print(sentences_reuters_2[:3])
sentences_reuters_4 = read_sentences_from_txt(DATA_PATH_reuters_4)
print(f"Loaded {len(sentences_reuters_4)} sentences.")
print(sentences_reuters_4[:3])
sentences_reuters_6 = read_sentences_from_txt(DATA_PATH_reuters_6)
print(f"Loaded {len(sentences_reuters_6)} sentences.")
print(sentences_reuters_6[:3])
sentences_reuters_8 = read_sentences_from_txt(DATA_PATH_reuters_8)
print(f"Loaded {len(sentences_reuters_8)} sentences.")
print(sentences_reuters_8[:3])


sentences_paris = ["Paris", "Capital of France", "largest city in France"]
sentences_paris_london = ["Paris", "London", "Amsterdam"]
sentences_london = ["London", "Capital of UK", "largest city in UK"]
# Out:
# Loaded 400 sentences.
# ['While it was being called mandatory , Dupont said authorities were not forcing people from their homes .', 'It was called mandatory , but Dupont said authorities did not force people to leave .', 'Michael Mitchell , the chief public defender in Baton Rouge who is representing Lee , did not answer his phone Wednesday afternoon .']
# Loaded 400 sentences.
# ['While it was being called mandatory , Dupont said authorities were not forcing people from their homes .', 'The euro < EUR = > was up 0.67 percent against the dollar at $ 1.1784 after rising to a three-month high earlier in the session above $ 1.18 .', 'Michael Mitchell , the chief public defender in Baton Rouge who is representing Lee , did not answer his phone Wednesday afternoon .']
# Loaded 400 sentences.
# ['How do I to score good marks in 12th boards?', 'How can we score excellent marks in class 12th board exams?', 'What is physical quantities and also its types?']
# Loaded 400 sentences.
# ...

# %%
embeddings_mrpc_high = encode_sentences(sentences_mrpc_high)
print(f"Embedding shape: {len(embeddings_mrpc_high)} x {len(embeddings_mrpc_high[0])}")
embeddings_mrpc_low = encode_sentences(sentences_mrpc_low)
print(f"Embedding shape: {len(embeddings_mrpc_low)} x {len(embeddings_mrpc_low[0])}")

embeddings_qqp_high = encode_sentences(sentences_qqp_high)
print(f"Embedding shape: {len(embeddings_qqp_high)} x {len(embeddings_qqp_high[0])}")
embeddings_qqp_low = encode_sentences(sentences_qqp_low)
print(f"Embedding shape: {len(embeddings_qqp_low)} x {len(embeddings_qqp_low[0])}")

embeddings_stsb_high = encode_sentences(sentences_stsb_high)
print(f"Embedding shape: {len(embeddings_stsb_high)} x {len(embeddings_stsb_high[0])}")
embeddings_stsb_low = encode_sentences(sentences_stsb_low)
print(f"Embedding shape: {len(embeddings_stsb_low)} x {len(embeddings_stsb_low[0])}")

embeddings_20newsgroups_2 = encode_sentences(sentences_20newsgroups_2)
print(f"Embedding shape: {len(embeddings_20newsgroups_2)} x {len(embeddings_20newsgroups_2[0])}")
embeddings_20newsgroups_4 = encode_sentences(sentences_20newsgroups_4)
print(f"Embedding shape: {len(embeddings_20newsgroups_4)} x {len(embeddings_20newsgroups_4[0])}")
embeddings_20newsgroups_6 = encode_sentences(sentences_20newsgroups_6)
print(f"Embedding shape: {len(embeddings_20newsgroups_6)} x {len(embeddings_20newsgroups_6[0])}")
embeddings_20newsgroups_8 = encode_sentences(sentences_20newsgroups_8)
print(f"Embedding shape: {len(embeddings_20newsgroups_8)} x {len(embeddings_20newsgroups_8[0])}") 
embeddings_20newsgroups_10 = encode_sentences(sentences_20newsgroups_10)
print(f"Embedding shape: {len(embeddings_20newsgroups_10)} x {len(embeddings_20newsgroups_10[0])}") 
embeddings_20newsgroups_12 = encode_sentences(sentences_20newsgroups_12)
print(f"Embedding shape: {len(embeddings_20newsgroups_12)} x {len(embeddings_20newsgroups_12[0])}") 
embeddings_20newsgroups_14 = encode_sentences(sentences_20newsgroups_14)
print(f"Embedding shape: {len(embeddings_20newsgroups_14)} x {len(embeddings_20newsgroups_14[0])}") 
embeddings_20newsgroups_16 = encode_sentences(sentences_20newsgroups_16)
print(f"Embedding shape: {len(embeddings_20newsgroups_16)} x {len(embeddings_20newsgroups_16[0])}") 
embeddings_20newsgroups_18 = encode_sentences(sentences_20newsgroups_18)
print(f"Embedding shape: {len(embeddings_20newsgroups_18)} x {len(embeddings_20newsgroups_18[0])}") 
embeddings_20newsgroups_20 = encode_sentences(sentences_20newsgroups_20)
print(f"Embedding shape: {len(embeddings_20newsgroups_20)} x {len(embeddings_20newsgroups_20[0])}") 

embeddings_agnews_1 = encode_sentences(sentences_agnews_1)
print(f"Embedding shape: {len(embeddings_agnews_1)} x {len(embeddings_agnews_1[0])}")
embeddings_agnews_2 = encode_sentences(sentences_agnews_2)
print(f"Embedding shape: {len(embeddings_agnews_2)} x {len(embeddings_agnews_2[0])}")
embeddings_agnews_3 = encode_sentences(sentences_agnews_3)
print(f"Embedding shape: {len(embeddings_agnews_3)} x {len(embeddings_agnews_3[0])}")
embeddings_agnews_4 = encode_sentences(sentences_agnews_4)
print(f"Embedding shape: {len(embeddings_agnews_4)} x {len(embeddings_agnews_4[0])}") 

embeddings_reuters_2 = encode_sentences(sentences_reuters_2)
print(f"Embedding shape: {len(embeddings_reuters_2)} x {len(embeddings_reuters_2[0])}")
embeddings_reuters_4 = encode_sentences(sentences_reuters_4)
print(f"Embedding shape: {len(embeddings_reuters_4)} x {len(embeddings_reuters_4[0])}")
embeddings_reuters_6 = encode_sentences(sentences_reuters_6)
print(f"Embedding shape: {len(embeddings_reuters_6)} x {len(embeddings_reuters_6[0])}")
embeddings_reuters_8 = encode_sentences(sentences_reuters_8)
print(f"Embedding shape: {len(embeddings_reuters_8)} x {len(embeddings_reuters_8[0])}")

embeddings_paris = encode_sentences(sentences_paris)
print(f"Embedding shape: {len(embeddings_paris)} x {len(embeddings_paris[0])}")
embeddings_paris_london = encode_sentences(sentences_paris_london)
print(f"Embedding shape: {len(embeddings_paris_london)} x {len(embeddings_paris_london[0])}")
embeddings_london = encode_sentences(sentences_london)
print(f"Embedding shape: {len(embeddings_london)} x {len(embeddings_london[0])}")
# Out:
# Embedding shape: 400 x 384
# Embedding shape: 400 x 384
# Embedding shape: 400 x 384
# Embedding shape: 400 x 384
# Embedding shape: 400 x 384
# Embedding shape: 400 x 384
# Embedding shape: 1000 x 384
# Embedding shape: 1000 x 384
# Embedding shape: 1000 x 384
# Embedding shape: 1000 x 384
# Embedding shape: 1000 x 384
# Embedding shape: 1000 x 384
# Embedding shape: 1000 x 384
# Embedding shape: 1000 x 384
# Embedding shape: 1000 x 384
# Embedding shape: 1000 x 384
# Embedding shape: 1000 x 384
# Embedding shape: 1000 x 384
# Embedding shape: 1000 x 384
# Embedding shape: 1000 x 384
# Embedding shape: 80 x 384
# Embedding shape: 80 x 384
# Embedding shape: 80 x 384
# Embedding shape: 80 x 384
# Embedding shape: 3 x 384
# Embedding shape: 3 x 384
# Embedding shape: 3 x 384

# %%
print("\nMRPC Low Diversity:")
print("Mean Pairwise Distance:", mean_pairwise_distance(embeddings_mrpc_low))
print("Distance Dispersion:", distance_dispersion(embeddings_mrpc_low))
print("Cluster Inertia Diversity:", cluster_inertia_diversity(embeddings_mrpc_low))
print("Radius Diversity:", radius_diversity(embeddings_mrpc_low))
# try:
#     print("Convex Hull Volume:", convex_hull_volume(embeddings_mrpc_low))
# except Exception as e:
#     print("Convex Hull Volume: error -", e)
print("\nMRPC High Diversity:")
print("Mean Pairwise Distance:", mean_pairwise_distance(embeddings_mrpc_high))
print("Distance Dispersion:", distance_dispersion(embeddings_mrpc_high))
print("Cluster Inertia Diversity:", cluster_inertia_diversity(embeddings_mrpc_high))
print("Radius Diversity:", radius_diversity(embeddings_mrpc_high))
# try:
#     print("Convex Hull Volume:", convex_hull_volume(embeddings_mrpc_high))
# except Exception as e:
#     print("Convex Hull Volume: error -", e)

print("\nQQP Low Diversity:")
print("Mean Pairwise Distance:", mean_pairwise_distance(embeddings_qqp_low))
print("Distance Dispersion:", distance_dispersion(embeddings_qqp_low))
print("Cluster Inertia Diversity:", cluster_inertia_diversity(embeddings_qqp_low))
print("Radius Diversity:", radius_diversity(embeddings_qqp_low))
# try:
#     print("Convex Hull Volume:", convex_hull_volume(embeddings_qqp_low))
# except Exception as e:
#     print("Convex Hull Volume: error -", e)
print("\n QQP High Diversity:")
print("Mean Pairwise Distance:", mean_pairwise_distance(embeddings_qqp_high))
print("Distance Dispersion:", distance_dispersion(embeddings_qqp_high))
print("Cluster Inertia Diversity:", cluster_inertia_diversity(embeddings_qqp_high))
print("Radius Diversity:", radius_diversity(embeddings_qqp_high))
# try:
#     print("Convex Hull Volume:", convex_hull_volume(embeddings_qqp_high))
# except Exception as e:
#     print("Convex Hull Volume: error -", e)

print("\nSTSB Low Diversity:")
print("Mean Pairwise Distance:", mean_pairwise_distance(embeddings_stsb_low))
print("Distance Dispersion:", distance_dispersion(embeddings_stsb_low))
print("Cluster Inertia Diversity:", cluster_inertia_diversity(embeddings_stsb_low))
print("Radius Diversity:", radius_diversity(embeddings_stsb_low))
# try:
#     print("Convex Hull Volume:", convex_hull_volume(embeddings_stsb_low))
# except Exception as e:
#     print("Convex Hull Volume: error -", e)
print("STSB High Diversity:")
print("Mean Pairwise Distance:", mean_pairwise_distance(embeddings_stsb_high))
print("Distance Dispersion:", distance_dispersion(embeddings_stsb_high))
print("Cluster Inertia Diversity:", cluster_inertia_diversity(embeddings_stsb_high))
print("Radius Diversity:", radius_diversity(embeddings_stsb_high))
# try:
#     print("Convex Hull Volume:", convex_hull_volume(embeddings_stsb_high))
# except Exception as e:
#     print("Convex Hull Volume: error -", e)

print("\n20 Newsgroups 2 Topics:")
print("Mean Pairwise Distance:", mean_pairwise_distance(embeddings_20newsgroups_2))
print("Distance Dispersion:", distance_dispersion(embeddings_20newsgroups_2))
print("Cluster Inertia Diversity:", cluster_inertia_diversity(embeddings_20newsgroups_2))
print("Radius Diversity:", radius_diversity(embeddings_20newsgroups_2))
# try:
#     print("Convex Hull Volume:", convex_hull_volume(embeddings_20newsgroups_2))
# except Exception as e:
#     print("Convex Hull Volume: error -", e)
print("\n20 Newsgroups 4 Topics:")
print("Mean Pairwise Distance:", mean_pairwise_distance(embeddings_20newsgroups_4))
print("Distance Dispersion:", distance_dispersion(embeddings_20newsgroups_4))
print("Cluster Inertia Diversity:", cluster_inertia_diversity(embeddings_20newsgroups_4))
print("Radius Diversity:", radius_diversity(embeddings_20newsgroups_4))
# try:
#     print("Convex Hull Volume:", convex_hull_volume(embeddings_20newsgroups_4))
# except Exception as e:
#     print("Convex Hull Volume: error -", e)
print("\n20 Newsgroups 6 Topics:")
print("Mean Pairwise Distance:", mean_pairwise_distance(embeddings_20newsgroups_6))
print("Distance Dispersion:", distance_dispersion(embeddings_20newsgroups_6))
print("Cluster Inertia Diversity:", cluster_inertia_diversity(embeddings_20newsgroups_6))
print("Radius Diversity:", radius_diversity(embeddings_20newsgroups_6))
# try:
#     print("Convex Hull Volume:", convex_hull_volume(embeddings_20newsgroups_6))
# except Exception as e:
#     print("Convex Hull Volume: error -", e)
print("\n20 Newsgroups 8 Topics:")
print("Mean Pairwise Distance:", mean_pairwise_distance(embeddings_20newsgroups_8))
print("Distance Dispersion:", distance_dispersion(embeddings_20newsgroups_8))
print("Cluster Inertia Diversity:", cluster_inertia_diversity(embeddings_20newsgroups_8))
print("Radius Diversity:", radius_diversity(embeddings_20newsgroups_8))
# try:
#     print("Convex Hull Volume:", convex_hull_volume(embeddings_20newsgroups_8))
# except Exception as e:
#     print("Convex Hull Volume: error -", e)   
print("\n20 Newsgroups 10 Topics:")
print("Mean Pairwise Distance:", mean_pairwise_distance(embeddings_20newsgroups_10))
print("Distance Dispersion:", distance_dispersion(embeddings_20newsgroups_10))
print("Cluster Inertia Diversity:", cluster_inertia_diversity(embeddings_20newsgroups_10))
print("Radius Diversity:", radius_diversity(embeddings_20newsgroups_10))  
# try:
#     print("Convex Hull Volume:", convex_hull_volume(embeddings_20newsgroups_10))
# except Exception as e:
#     print("Convex Hull Volume: error -", e)  
print("\n20 Newsgroups 12 Topics:")
print("Mean Pairwise Distance:", mean_pairwise_distance(embeddings_20newsgroups_12))
print("Distance Dispersion:", distance_dispersion(embeddings_20newsgroups_12))
print("Cluster Inertia Diversity:", cluster_inertia_diversity(embeddings_20newsgroups_12))
print("Radius Diversity:", radius_diversity(embeddings_20newsgroups_12))
# try:
#     print("Convex Hull Volume:", convex_hull_volume(embeddings_20newsgroups_12))
# except Exception as e:
#     print("Convex Hull Volume: error -", e)
print("\n20 Newsgroups 14 Topics:")
print("Mean Pairwise Distance:", mean_pairwise_distance(embeddings_20newsgroups_14))
print("Distance Dispersion:", distance_dispersion(embeddings_20newsgroups_14))
print("Cluster Inertia Diversity:", cluster_inertia_diversity(embeddings_20newsgroups_14))
print("Radius Diversity:", radius_diversity(embeddings_20newsgroups_14))
# try:
#     print("Convex Hull Volume:", convex_hull_volume(embeddings_20newsgroups_14))
# except Exception as e:
#     print("Convex Hull Volume: error -", e) 
print("\n20 Newsgroups 16 Topics:")
print("Mean Pairwise Distance:", mean_pairwise_distance(embeddings_20newsgroups_16))
print("Distance Dispersion:", distance_dispersion(embeddings_20newsgroups_16))
print("Cluster Inertia Diversity:", cluster_inertia_diversity(embeddings_20newsgroups_16))
print("Radius Diversity:", radius_diversity(embeddings_20newsgroups_16))
# try:
#     print("Convex Hull Volume:", convex_hull_volume(embeddings_20newsgroups_16))
# except Exception as e:
#     print("Convex Hull Volume: error -", e) 
print("\n20 Newsgroups 18 Topics:")
print("Mean Pairwise Distance:", mean_pairwise_distance(embeddings_20newsgroups_18))
print("Distance Dispersion:", distance_dispersion(embeddings_20newsgroups_18))
print("Cluster Inertia Diversity:", cluster_inertia_diversity(embeddings_20newsgroups_18))
print("Radius Diversity:", radius_diversity(embeddings_20newsgroups_18))
# try:
#     print("Convex Hull Volume:", convex_hull_volume(embeddings_20newsgroups_18))
# except Exception as e:
#     print("Convex Hull Volume: error -", e) 
print("\n20 Newsgroups 20 Topics:")
print("Mean Pairwise Distance:", mean_pairwise_distance(embeddings_20newsgroups_20))
print("Distance Dispersion:", distance_dispersion(embeddings_20newsgroups_20))
print("Cluster Inertia Diversity:", cluster_inertia_diversity(embeddings_20newsgroups_20))
print("Radius Diversity:", radius_diversity(embeddings_20newsgroups_20))
# try:
#     print("Convex Hull Volume:", convex_hull_volume(embeddings_20newsgroups_20))
# except Exception as e:
#     print("Convex Hull Volume: error -", e)  

print("\nAG News 1 Topic:")
print("Mean Pairwise Distance:", mean_pairwise_distance(embeddings_agnews_1))
print("Distance Dispersion:", distance_dispersion(embeddings_agnews_1))
print("Cluster Inertia Diversity:", cluster_inertia_diversity(embeddings_agnews_1))
print("Radius Diversity:", radius_diversity(embeddings_agnews_1))
# try:
#     print("Convex Hull Volume:", convex_hull_volume(embeddings_agnews_1))
# except Exception as e:
#     print("Convex Hull Volume: error -", e)
print("\nAG News 2 Topics:")
print("Mean Pairwise Distance:", mean_pairwise_distance(embeddings_agnews_2))
print("Distance Dispersion:", distance_dispersion(embeddings_agnews_2))
print("Cluster Inertia Diversity:", cluster_inertia_diversity(embeddings_agnews_2))
print("Radius Diversity:", radius_diversity(embeddings_agnews_2))
# try:
#     print("Convex Hull Volume:", convex_hull_volume(embeddings_agnews_2))
# except Exception as e:
#     print("Convex Hull Volume: error -", e)
print("\nAG News 3 Topics:")
print("Mean Pairwise Distance:", mean_pairwise_distance(embeddings_agnews_3))
print("Distance Dispersion:", distance_dispersion(embeddings_agnews_3))
print("Cluster Inertia Diversity:", cluster_inertia_diversity(embeddings_agnews_3))
print("Radius Diversity:", radius_diversity(embeddings_agnews_3))
# try:
#     print("Convex Hull Volume:", convex_hull_volume(embeddings_agnews_3))
# except Exception as e:
#     print("Convex Hull Volume: error -", e)
print("\nAG News 4 Topics:")
print("Mean Pairwise Distance:", mean_pairwise_distance(embeddings_agnews_4))
print("Distance Dispersion:", distance_dispersion(embeddings_agnews_4))
print("Cluster Inertia Diversity:", cluster_inertia_diversity(embeddings_agnews_4))
print("Radius Diversity:", radius_diversity(embeddings_agnews_4))
# try:
#     print("Convex Hull Volume:", convex_hull_volume(embeddings_agnews_4))
# except Exception as e:
#     print("Convex Hull Volume: error -", e)   

print("\nReuters 2 Topics:")
print("Mean Pairwise Distance:", mean_pairwise_distance(embeddings_reuters_2))
print("Distance Dispersion:", distance_dispersion(embeddings_reuters_2))
print("Cluster Inertia Diversity:", cluster_inertia_diversity(embeddings_reuters_2))
print("Radius Diversity:", radius_diversity(embeddings_reuters_2))
# try:
#     print("Convex Hull Volume:", convex_hull_volume(embeddings_reuters_2))
# except Exception as e:
#     print("Convex Hull Volume: error -", e)
print("\nReuters 4 Topics:")
print("Mean Pairwise Distance:", mean_pairwise_distance(embeddings_reuters_4))
print("Distance Dispersion:", distance_dispersion(embeddings_reuters_4))
print("Cluster Inertia Diversity:", cluster_inertia_diversity(embeddings_reuters_4))
print("Radius Diversity:", radius_diversity(embeddings_reuters_4))
# try:
#     print("Convex Hull Volume:", convex_hull_volume(embeddings_reuters_4))
# except Exception as e:
#     print("Convex Hull Volume: error -", e)
print("\nReuters 6 Topics:")
print("Mean Pairwise Distance:", mean_pairwise_distance(embeddings_reuters_6))
print("Distance Dispersion:", distance_dispersion(embeddings_reuters_6))
print("Cluster Inertia Diversity:", cluster_inertia_diversity(embeddings_reuters_6))
print("Radius Diversity:", radius_diversity(embeddings_reuters_6))
# try:
#     print("Convex Hull Volume:", convex_hull_volume(embeddings_reuters_6))
# except Exception as e:
#     print("Convex Hull Volume: error -", e)
print("\nReuters 8 Topics:")
print("Mean Pairwise Distance:", mean_pairwise_distance(embeddings_reuters_8))
print("Distance Dispersion:", distance_dispersion(embeddings_reuters_8))
print("Cluster Inertia Diversity:", cluster_inertia_diversity(embeddings_reuters_8))
print("Radius Diversity:", radius_diversity(embeddings_reuters_8))
# try:
#     print("Convex Hull Volume:", convex_hull_volume(embeddings_reuters_8))
# except Exception as e:
#     print("Convex Hull Volume: error -", e)

print("\nParis Sentences:")
print("Mean Pairwise Distance:", mean_pairwise_distance(embeddings_paris))
print("Distance Dispersion:", distance_dispersion(embeddings_paris))
print("Cluster Inertia Diversity:", cluster_inertia_diversity(embeddings_paris))
print("Radius Diversity:", radius_diversity(embeddings_paris))  

print("\nParis vs London Sentences:")
print("Mean Pairwise Distance:", mean_pairwise_distance(embeddings_paris_london))
print("Distance Dispersion:", distance_dispersion(embeddings_paris_london))
print("Cluster Inertia Diversity:", cluster_inertia_diversity(embeddings_paris_london))
print("Radius Diversity:", radius_diversity(embeddings_paris_london))

print("\nLondon Sentences:")
print("Mean Pairwise Distance:", mean_pairwise_distance(embeddings_london))
print("Distance Dispersion:", distance_dispersion(embeddings_london))
print("Cluster Inertia Diversity:", cluster_inertia_diversity(embeddings_london))
print("Radius Diversity:", radius_diversity(embeddings_london))
# Out:
# MRPC Low Diversity:
# Mean Pairwise Distance: 0.9386826314532487
# Distance Dispersion: 74906.87398996924
# Cluster Inertia Diversity: 327.1226579175966
# Radius Diversity: 0.04142868355787768
#
# MRPC High Diversity:
# Mean Pairwise Distance: 0.9430657245671221
# Distance Dispersion: 75256.64482045635
# Cluster Inertia Diversity: 331.09165281974697
# Radius Diversity: 0.041562529403472485
#
# QQP Low Diversity:
# Mean Pairwise Distance: 0.9455451287116612
# Distance Dispersion: 75454.50127119056
# Cluster Inertia Diversity: 322.90224212319225
# Radius Diversity: 0.04156491979753916
#
#  QQP High Diversity:
# /opt/anaconda3/envs/measure_diversity/lib/python3.11/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /opt/anaconda3/envs/measure_diversity/lib/python3.11/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# ...

# %%
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA

# %%
pca = PCA(n_components=2)
embeddings_2d_mrpc_low = pca.fit_transform(embeddings_mrpc_low)
plt.scatter(embeddings_2d_mrpc_low[:,0], embeddings_2d_mrpc_low[:,1])
plt.title("SBERT Embeddings (PCA 2D) - MRPC Low-diversity")
plt.xlabel("PC1")
plt.ylabel("PC2")
plt.show()
pca = PCA(n_components=2)
embeddings_2d_mrpc_high = pca.fit_transform(embeddings_mrpc_high)
plt.scatter(embeddings_2d_mrpc_high[:,0], embeddings_2d_mrpc_high[:,1])
plt.title("SBERT Embeddings (PCA 2D) - MRPC High-diversity")
plt.xlabel("PC1")
plt.ylabel("PC2")
plt.show()

pca = PCA(n_components=2)
embeddings_2d_qqp_low = pca.fit_transform(embeddings_qqp_low)
plt.scatter(embeddings_2d_qqp_low[:,0], embeddings_2d_qqp_low[:,1])
plt.title("SBERT Embeddings (PCA 2D) - QQP Low-diversity")
plt.xlabel("PC1")
plt.ylabel("PC2")
plt.show()
pca = PCA(n_components=2)
embeddings_2d_qqp_high = pca.fit_transform(embeddings_qqp_high)
plt.scatter(embeddings_2d_qqp_high[:,0], embeddings_2d_qqp_high[:,1])
plt.title("SBERT Embeddings (PCA 2D) - QQP High-diversity")
plt.xlabel("PC1")
plt.ylabel("PC2")
plt.show()

pca = PCA(n_components=2)
embeddings_2d_stsb_low = pca.fit_transform(embeddings_stsb_low)
plt.scatter(embeddings_2d_stsb_low[:,0], embeddings_2d_stsb_low[:,1])
plt.title("SBERT Embeddings (PCA 2D) - STSB Low-diversity")
plt.xlabel("PC1")
plt.ylabel("PC2")
plt.show()
pca = PCA(n_components=2)
embeddings_2d_stsb_high = pca.fit_transform(embeddings_stsb_high)
plt.scatter(embeddings_2d_stsb_high[:,0], embeddings_2d_stsb_high[:,1])
plt.title("SBERT Embeddings (PCA 2D) - STSB High-diversity")
plt.xlabel("PC1")
plt.ylabel("PC2")
plt.show()

pca = PCA(n_components=2)
embeddings_2d_20newsgroups_2 = pca.fit_transform(embeddings_20newsgroups_2)
plt.scatter(embeddings_2d_20newsgroups_2[:,0], embeddings_2d_20newsgroups_2[:,1])
plt.title("SBERT Embeddings (PCA 2D) - 20 Newsgroups 2 Topics")
plt.xlabel("PC1")
plt.ylabel("PC2")
plt.show()
pca = PCA(n_components=2)
embeddings_2d_20newsgroups_4 = pca.fit_transform(embeddings_20newsgroups_4)
plt.scatter(embeddings_2d_20newsgroups_4[:,0], embeddings_2d_20newsgroups_4[:,1])
plt.title("SBERT Embeddings (PCA 2D) - 20 Newsgroups 4 Topics")
plt.xlabel("PC1")
plt.ylabel("PC2")
plt.show()
pca = PCA(n_components=2)
embeddings_2d_20newsgroups_6 = pca.fit_transform(embeddings_20newsgroups_6)
plt.scatter(embeddings_2d_20newsgroups_6[:,0], embeddings_2d_20newsgroups_6[:,1])
plt.title("SBERT Embeddings (PCA 2D) - 20 Newsgroups 6 Topics")
plt.xlabel("PC1")
plt.ylabel("PC2")
plt.show()
pca = PCA(n_components=2)
embeddings_2d_20newsgroups_8 = pca.fit_transform(embeddings_20newsgroups_8)
plt.scatter(embeddings_2d_20newsgroups_8[:,0], embeddings_2d_20newsgroups_8[:,1])
plt.title("SBERT Embeddings (PCA 2D) - 20 Newsgroups 8 Topics")
plt.xlabel("PC1")
plt.ylabel("PC2")
plt.show()
pca = PCA(n_components=2)
embeddings_2d_20newsgroups_10 = pca.fit_transform(embeddings_20newsgroups_10)
plt.scatter(embeddings_2d_20newsgroups_10[:,0], embeddings_2d_20newsgroups_10[:,1])
plt.title("SBERT Embeddings (PCA 2D) - 20 Newsgroups 10 Topics")
plt.xlabel("PC1")
plt.ylabel("PC2")
plt.show()
pca = PCA(n_components=2)
embeddings_2d_20newsgroups_12 = pca.fit_transform(embeddings_20newsgroups_12)
plt.scatter(embeddings_2d_20newsgroups_12[:,0], embeddings_2d_20newsgroups_12[:,1])
plt.title("SBERT Embeddings (PCA 2D) - 20 Newsgroups 12 Topics")
plt.xlabel("PC1")
plt.ylabel("PC2")
plt.show()
pca = PCA(n_components=2)
embeddings_2d_20newsgroups_14 = pca.fit_transform(embeddings_20newsgroups_14)
plt.scatter(embeddings_2d_20newsgroups_14[:,0], embeddings_2d_20newsgroups_14[:,1])
plt.title("SBERT Embeddings (PCA 2D) - 20 Newsgroups 14 Topics")
plt.xlabel("PC1")
plt.ylabel("PC2")
plt.show()
pca = PCA(n_components=2)
embeddings_2d_20newsgroups_16 = pca.fit_transform(embeddings_20newsgroups_16)
plt.scatter(embeddings_2d_20newsgroups_16[:,0], embeddings_2d_20newsgroups_16[:,1])
plt.title("SBERT Embeddings (PCA 2D) - 20 Newsgroups 16 Topics")
plt.xlabel("PC1")
plt.ylabel("PC2")
plt.show()
pca = PCA(n_components=2)
embeddings_2d_20newsgroups_18 = pca.fit_transform(embeddings_20newsgroups_18)
plt.scatter(embeddings_2d_20newsgroups_18[:,0], embeddings_2d_20newsgroups_18[:,1])
plt.title("SBERT Embeddings (PCA 2D) - 20 Newsgroups 18 Topics")
plt.xlabel("PC1")
plt.ylabel("PC2")
plt.show()  
pca = PCA(n_components=2)
embeddings_2d_20newsgroups_20 = pca.fit_transform(embeddings_20newsgroups_20)
plt.scatter(embeddings_2d_20newsgroups_20[:,0], embeddings_2d_20newsgroups_20[:,1])
plt.title("SBERT Embeddings (PCA 2D) - 20 Newsgroups 20 Topics")
plt.xlabel("PC1")
plt.ylabel("PC2")
plt.show()

pca = PCA(n_components=2)
embeddings_2d_agnews_1 = pca.fit_transform(embeddings_agnews_1)
plt.scatter(embeddings_2d_agnews_1[:,0], embeddings_2d_agnews_1[:,1])
plt.title("SBERT Embeddings (PCA 2D) - AG News 1 Topic")
plt.xlabel("PC1")
plt.ylabel("PC2")
plt.show()
pca = PCA(n_components=2)
embeddings_2d_agnews_2 = pca.fit_transform(embeddings_agnews_2)
plt.scatter(embeddings_2d_agnews_2[:,0], embeddings_2d_agnews_2[:,1])
plt.title("SBERT Embeddings (PCA 2D) - AG News 2 Topics")
plt.xlabel("PC1")
plt.ylabel("PC2")
plt.show()
pca = PCA(n_components=2)
embeddings_2d_agnews_3 = pca.fit_transform(embeddings_agnews_3)
plt.scatter(embeddings_2d_agnews_3[:,0], embeddings_2d_agnews_3[:,1])
plt.title("SBERT Embeddings (PCA 2D) - AG News 3 Topics")
plt.xlabel("PC1")
plt.ylabel("PC2")
plt.show()
pca = PCA(n_components=2)
embeddings_2d_agnews_4 = pca.fit_transform(embeddings_agnews_4)
plt.scatter(embeddings_2d_agnews_4[:,0], embeddings_2d_agnews_4[:,1])
plt.title("SBERT Embeddings (PCA 2D) - AG News 4 Topics")
plt.xlabel("PC1")
plt.ylabel("PC2")
plt.show()  

pca = PCA(n_components=2)
embeddings_2d_reuters_2 = pca.fit_transform(embeddings_reuters_2)
plt.scatter(embeddings_2d_reuters_2[:,0], embeddings_2d_reuters_2[:,1])
plt.title("SBERT Embeddings (PCA 2D) - Reuters 2 Topics")
plt.xlabel("PC1")
plt.ylabel("PC2")
plt.show()
pca = PCA(n_components=2)
embeddings_2d_reuters_4 = pca.fit_transform(embeddings_reuters_4)
plt.scatter(embeddings_2d_reuters_4[:,0], embeddings_2d_reuters_4[:,1])
plt.title("SBERT Embeddings (PCA 2D) - Reuters 4 Topics")
plt.xlabel("PC1")
plt.ylabel("PC2")
plt.show()
pca = PCA(n_components=2)
embeddings_2d_reuters_6 = pca.fit_transform(embeddings_reuters_6)
plt.scatter(embeddings_2d_reuters_6[:,0], embeddings_2d_reuters_6[:,1])
plt.title("SBERT Embeddings (PCA 2D) - Reuters 6 Topics")
plt.xlabel("PC1")
plt.ylabel("PC2")
plt.show()
pca = PCA(n_components=2)
embeddings_2d_reuters_8 = pca.fit_transform(embeddings_reuters_8)
plt.scatter(embeddings_2d_reuters_8[:,0], embeddings_2d_reuters_8[:,1])
plt.title("SBERT Embeddings (PCA 2D) - Reuters 8 Topics")
plt.xlabel("PC1")
plt.ylabel("PC2")
plt.show()

pca = PCA(n_components=2)
embeddings_2d_paris = pca.fit_transform(embeddings_paris)
plt.scatter(embeddings_2d_paris[:,0], embeddings_2d_paris[:,1])
plt.title("SBERT Embeddings (PCA 2D) - Paris Sentences")
plt.xlabel("PC1")
plt.ylabel("PC2")
plt.show()

pca = PCA(n_components=2)
embeddings_2d_paris_london = pca.fit_transform(embeddings_paris_london)
plt.scatter(embeddings_2d_paris_london[:,0], embeddings_2d_paris_london[:,1])
plt.title("SBERT Embeddings (PCA 2D) - Paris vs London Sentences")
plt.xlabel("PC1")
plt.ylabel("PC2")
plt.show()

pca = PCA(n_components=2)
embeddings_2d_london = pca.fit_transform(embeddings_london)
plt.scatter(embeddings_2d_london[:,0], embeddings_2d_london[:,1])
plt.title("SBERT Embeddings (PCA 2D) - London Sentences")
plt.xlabel("PC1")
plt.ylabel("PC2")
plt.show()
# Out:
# /opt/anaconda3/envs/measure_diversity/lib/python3.11/site-packages/sklearn/utils/extmath.py:350: RuntimeWarning: divide by zero encountered in matmul
#   Q, _ = normalizer(A @ Q)
# /opt/anaconda3/envs/measure_diversity/lib/python3.11/site-packages/sklearn/utils/extmath.py:350: RuntimeWarning: overflow encountered in matmul
#   Q, _ = normalizer(A @ Q)
# /opt/anaconda3/envs/measure_diversity/lib/python3.11/site-packages/sklearn/utils/extmath.py:350: RuntimeWarning: invalid value encountered in matmul
#   Q, _ = normalizer(A @ Q)
# /opt/anaconda3/envs/measure_diversity/lib/python3.11/site-packages/sklearn/utils/extmath.py:351: RuntimeWarning: divide by zero encountered in matmul
#   Q, _ = normalizer(A.T @ Q)
# /opt/anaconda3/envs/measure_diversity/lib/python3.11/site-packages/sklearn/utils/extmath.py:351: RuntimeWarning: overflow encountered in matmul
#   Q, _ = normalizer(A.T @ Q)
# ...
