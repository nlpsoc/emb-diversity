# %%
from emb_diversity import plot_2d, plot_3d
import numpy as np
import warnings
warnings.filterwarnings("ignore", module="umap")

# %%
vectors_1 = np.random.randn(100, 384) * 5.0 # high variance
vectors_2 = np.random.randn(100, 384) * 0.5 # low variance
vectors_1
# Out:
# array([[ 4.98941772,  7.70786383, -4.98173495, ..., -9.75285029,
#         -8.14837841, -2.10180866],
#        [ 2.17461769, -7.70709188,  0.85256828, ..., -2.30351824,
#         -2.0472099 ,  6.02634974],
#        [ 1.56246706, -1.35809192,  0.36161558, ...,  1.72204392,
#          3.25584493,  1.78362219],
#        ...,
#        [-7.91413172,  3.39020285, -3.47828861, ...,  1.64814333,
#          0.3502626 , -2.37290046],
#        [-5.14146711,  0.61935073, -6.74339322, ...,  5.13470405,
#         -9.1513015 ,  3.44584816],
#        [ 0.18987862,  4.60791108,  1.81652286, ...,  2.77847209,
#          1.70901993, 10.38894554]], shape=(100, 384))

# %% [markdown]
# # Two-dimensional Plotting

# %% [markdown]
# ### We support plotting with t-SNE, UMAP and PCA (default):

# %%
plot_2d(vectors_1, method="tsne")
# Out:
# (<Figure size 800x600 with 1 Axes>,
#  <Axes: title={'center': '2D Projection (TSNE)'}>)

# %%
plot_2d(vectors_1, method="umap")
# Out:
# (<Figure size 800x600 with 1 Axes>,
#  <Axes: title={'center': '2D Projection (UMAP)'}>)

# %%
plot_2d(vectors_1, method="pca")
# Out:
# (<Figure size 800x600 with 1 Axes>,
#  <Axes: title={'center': '2D Projection (PCA)'}>)

# %% [markdown]
# ### We support plotting multiple datasets simultaneously:

# %%
plot_2d([vectors_1, vectors_2], method="tsne")
# Out:
# (<Figure size 800x600 with 1 Axes>,
#  <Axes: title={'center': '2D Projection (TSNE)'}>)

# %%
# Dataset labels can be given manually
plot_2d([vectors_1, vectors_2], method="pca", labels=["d1", "d2"])
# Out:
# (<Figure size 800x600 with 1 Axes>,
#  <Axes: title={'center': '2D Projection (PCA)'}>)

# %% [markdown]
# # Three-dimensional Plotting

# %%
plot_3d([vectors_1, vectors_2], method="umap")

# %%
plot_3d([vectors_1, vectors_2], method="tsne", labels=["Dataset A", "Dataset B"])

# %%
plot_3d([vectors_1, vectors_2], method="pca")
