# %%
from measure_diversity import pairwise_diversity, two_d
points_equi = two_d.create_normed_datapoints(n=8)
two_d.plot_points(points_equi, title="8 Uniform Points Around Circle")
points_first_quad = two_d.create_normed_datapoints(n=8, quads=[1])
two_d.plot_points(points_first_quad, title="8 Points in First Quadrant of Circle")
points_first_and_third_quad = two_d.create_normed_datapoints(n=8, quads=[1, 3])
two_d.plot_points(points_first_and_third_quad, title="8 Points in First and Third Quadrants of Circle")
points_second_quad = two_d.create_normed_datapoints(n=8, quads=[2])
two_d.plot_points(points_second_quad, title="8 Points in Second Quadrant of Circle")

# %%
print(pairwise_diversity(points_equi))
print(pairwise_diversity(points_first_and_third_quad))
assert pairwise_diversity(points_equi) > pairwise_diversity(points_first_and_third_quad)
# Out:
# 1.1428571428571428
# 1.1428571428571428
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[8], line 3
#       1 print(pairwise_diversity(points_equi))
#       2 print(pairwise_diversity(points_first_and_third_quad))
# ----> 3 assert pairwise_diversity(points_equi) > pairwise_diversity(points_first_and_third_quad)
#
# AssertionError:

# %%
print(pairwise_diversity(points_equi) )
print(pairwise_diversity(points_first_quad))
assert pairwise_diversity(points_equi) > pairwise_diversity(points_first_quad)
# Out:
# 1.1428571428571428
# 0.21351009893020126

# %%
print(pairwise_diversity(points_first_and_third_quad))
print(pairwise_diversity(points_first_quad))
assert pairwise_diversity(points_first_and_third_quad) > pairwise_diversity(points_first_quad)
# Out:
# 1.1428571428571428
# 0.21351009893020126

# %%
import pytest
print(pairwise_diversity(points_first_quad))
print(pairwise_diversity(points_second_quad))
assert pairwise_diversity(points_first_quad) == pytest.approx(pairwise_diversity(points_second_quad))
# Out:
# 0.21351009893020126
# 0.21351009893020115

# %%
print(pairwise_diversity(two_d.create_normed_datapoints(n=2)))
print(pairwise_diversity(two_d.create_normed_datapoints(n=2, quads=[1, 3])))
# Out:
# 2.0
# 2.0

# %%
two_d.plot_points(two_d.create_normed_datapoints(n=3, quads=[1, 2, 3, 4]), title="2 Uniform Points Around Circle")
two_d.create_normed_datapoints(n=3)
# Out:
# [(1.0, 0.0),
#  (-0.49999999999999983, 0.8660254037844387),
#  (-0.5000000000000004, -0.8660254037844384)]

# %%
two
